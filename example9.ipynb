# %%
import chit

chat = chit.Chat()

# %%
chat.commit("Hello, world!")
chat.commit()
# Out:
# Hi there! It's great to connect with you. How can I help you today? Whether you have a question, need information, or just want to chat, I'm here to assist. Feel free to let me know what's on your mind!

# %%
prompt = chit.textput()
# Out:
# Textarea(value='', layout=Layout(height='200px', width='100%'), placeholder='Type your message here...')

# %%
chat.commit(prompt.value)

# %%
chat.commit()
# Out:
# # Markdown Showcase
#
# You're doing a great job testing markdown! Here's a comprehensive example with various markdown elements:
#
# ## Text Formatting
#
# *Italics* and **bold** are working well. You can also do ***bold italics*** or ~~strikethrough~~ text.
#
# Sometimes you need ^superscript^ or ~

# %%
chat.commit("I think you got cut off? Did you just generate your own stop character by mistake or something?")
chat.commit()
# Out:
# You're right, I did get cut off! I apologize for that error. Let me provide a complete markdown showcase without any accidental truncation:
#
# # Markdown Showcase
#
# ## Text Formatting
#
# *Italics* and **bold** are working well. You can also do ***bold italics*** or ~~strikethrough~~ text.
#
# Sometimes you need <sup>superscript</sup> or <sub>subscript</sub> elements (note that these use HTML tags).
#
# ## Lists
#
# ### Ordered Lists
# 1. First item
# 2. Second item
#    1. Nested item
#    2. Another nested item
# 3. Third item
#
# ### Unordered Lists
# - Bullet point
# - Another point
#   * Nested point with different marker
#   * Another nested point
# - Back to the main level
#
# ## Code Examples
#
# Inline code: `const greeting = "Hello, world!";`
#
# ```javascript
# // A more complex code block
# function calculateFactorial(n) {
#   if (n <= 1) return 1;
#   return n * calculateFactorial(n - 1);
# }
#
# // Example usage
# ...

# %%
chat.checkout('094b8cbb')
chat.commit()
# Out:
# WARNING: Current message 094b8cbb already has a child message 43aac0b5 on branch master. Creating new branch master_1 to avoid overwriting.
# #

# %%
chat.checkout(-2)
chat.commit()
# Out:
# WARNING: Current message 094b8cbb already has a child message 43aac0b5 on branch master. Creating new branch master_2 to avoid overwriting.
# # Markdown Showcase
#
# I'd be happy to create a complex markdown example for your testing! Here's a variety of markdown elements combined into one comprehensive sample:
#
# ## 1. Text Formatting
#
# *Italic text* and _alternate italic_
# **Bold text** and __alternate bold__
# ***Bold and italic*** or ___another way___
# ~~Strikethrough~~ for deleted content
# `inline code` for technical terms
#
# ## 2. Lists
#
# ### Ordered List
# 1. First item
# 2. Second item
#    1. Nested item 2.1
#    2. Nested item 2.2
# 3. Third item with `code`
#
# ### Unordered List
# - Main bullet
#   * Sub-bullet with *italic*
#   * Another sub-bullet
# - Second bullet with **bold**
#   - Even deeper nesting
#     - And deeper still
#
# ## 3. Blockquotes
#
# > This is a simple blockquote
# >
# > > This is a nested blockquote with **formatting**
# > >
# ...

# %%
chat.commit("Can you do some code blocks containing complex HTML, including script tags and doctypes? And some markdown mixed with HTML? I'm basically testing a markdown renderer.")
chat.commit()
# Out:
# # Complex HTML and Markdown Examples
#
# Here are some complex code blocks containing HTML, scripting, and mixed markdown/HTML to help you test your markdown renderer:
#
# ## 1. Complete HTML Document with DOCTYPE and Scripts
#
# ```html
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Complex HTML Example</title>
#     <style>
#         body {
#             font-family: 'Segoe UI', Tahoma, Geneva, Verdana, sans-serif;
#             line-height: 1.6;
#             color: #333;
#             max-width: 1200px;
#             margin: 0 auto;
#             padding: 20px;
#         }
#         .container {
#             display: grid;
#             grid-template-columns: repeat(auto-fill, minmax(300px, 1fr));
#             gap: 20px;
#         }
#         .card {
#             border: 1px solid #ddd;
#             border-radius: 8px;
#             padding: 20px;
# ...

# %%
chat.show(-1)
# Out:
# # Complex HTML and Markdown Examples
#
# Here are some complex code blocks containing HTML, scripting, and mixed markdown/HTML to help you test your markdown renderer:
#
# ## 1. Complete HTML Document with DOCTYPE and Scripts
#
# ```html
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Complex HTML Example</title>
#     <style>
#         body {
#             font-family: 'Segoe UI', Tahoma, Geneva, Verdana, sans-serif;
#             line-height: 1.6;
#             color: #333;
#             max-width: 1200px;
#             margin: 0 auto;
#             padding: 20px;
#         }
#         .container {
#             display: grid;
#             grid-template-columns: repeat(auto-fill, minmax(300px, 1fr));
#             gap: 20px;
#         }
#         .card {
#             border: 1px solid #ddd;
#             border-radius: 8px;
#             padding: 20px;
# ...

# %%
problem = chat[-1].message["content"]

# %%
problem1= chit.read("bar.txt")
chat.commit(problem1)
chat.gui()
chat.rm(-1)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
chat2 = chit.Chat.clone("chitimps.json")
chat2.log()
# Out:
# [S_]0a2fae4b──[U_]0c718877──[A_]4b63df07──[U_]dc7df04f──[A_]f5eb2cb2──[U_]7fed9b3c──[A_]ef9cb79c── (master)
#             │                           │                           └─[U_]057e186c──[A_]aad7afbd──[U_]1557f58b──[A_]6b2686b6──[U_]c4820bf0──[A_]11e4c7a4──[U_]23b84bfb──[A_]ee07b62c──[U_]f4f5a248──[A_]e12a8f5f──[U_]add7cb48──[A_]ba0beafb──[U_]2cae65c6──[A_]de4fda97──[U_]3ebbc548──[A_]fd4cda1c──[U_]2eac5cf6──[A_]da112702──[U_]83d4bee9──[A_]bd4cec31──[U_]7a0dacfe──[A_]4f39ddb0── (vim)
#             │                           │                                                                                                                                                                                                                                                                                                                  └─[U_]dbef7c74──[A_]59c69b11──[U_]963484ff──[A_]de9fdabc──[U_]32e85bab──[A_]5bef56ec── (jupyter)
# ...

# %%
chat2.checkout(0)
chat2.commit(
"""I have written this Python module `chit` for creating and managing LLM chats in a git-like system.

One problem is that the visualization code is bugged when the chat messages contain script tags within markdown code blocks. 
"""
)
# Out:
# Analyze and review the folowing code:
#
# import tempfile
# import webbrowser
# import warnings
# from dataclasses import dataclass
# from typing import Optional, Pattern, Any, Literal
# from pathlib import Path
# import json
# import re
# import string
# import random
# import litellm
# from litellm import completion, stream_chunk_builder
# from chit.images import prepare_image_message
#
# from litellm.types.utils import (
#     # ModelResponse,
#     ChatCompletionMessageToolCall,
#     Function,
# )
# from litellm.types.utils import Message as ChatCompletionMessage
#
# CHIT_VERBOSE = True
#
#
# def chitverbose(*args, **kwargs):
#     """I can't get logging to print things in the right place in a notebook."""
#     if CHIT_VERBOSE:
#         print(*args, **kwargs)
#
# def read(file_path: str | Path) -> str:
#     with open(file_path, "r") as f:
#         return f.read()
#
# @dataclass
# class ChitMessage:
#     id: str
#     message: dict[str, str] | ChatCompletionMessage
# ...
